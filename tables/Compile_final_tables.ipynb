# %%
import pandas as pd
import glob

# %% [markdown]
# # Assembly statistics for assembly groups

# %%
assembly_stats = pd.read_csv('assembly_quast_report.txt', index_col=0)
groups = pd.read_csv('SampleList_2020_metaG.txt', sep='\t', index_col='Assembly_group')
quast = pd.read_csv('quast_report.txt', sep=
           '\t', index_col=0)
quast.index = quast.index.str.replace('_','-')

# %%
out_table = groups.merge(quast[['Total length', '# contigs', 'Largest contig', 'GC (%)', 'N50','L50']], left_index=True, right_index=True)
out_table['Depth'] = out_table.Depth_sizefrac.str.split('-').str[0]
out_table['Size_frac'] = out_table.Depth_sizefrac.str.split('-').str[1:].str.join('-')

# %%
out_table = out_table[['Sub_region',  'Depth', 'Size_frac','ERR_count', 'ERR_list', 'Total length',
       '# contigs', 'Largest contig', 'GC (%)', 'N50','L50']]
out_table.columns = ['sub_region',  'depth', 'size_fraction','total_err_count', 'err_list', 'total_length',
       'total_num_contigs', 'largest_contig', 'GC_percent', 'N50','L50']

# %%
out_table
# Out:
#                         sub_region depth size_fraction  total_err_count  \
# SPO-all-DCM-0.8-5.00       SPO-all   DCM      0.8-5.00               26
# SPO-all-DCM-180-2000.00    SPO-all   DCM   180-2000.00               16
# SPO-all-SRF-0.8-5.00       SPO-all   SRF      0.8-5.00               43
# SPO-all-SRF-180-2000.00    SPO-all   SRF   180-2000.00               33
# SPO-all-SRF-20-180.00      SPO-all   SRF     20-180.00               31
# ...                            ...   ...           ...              ...
# SPO-CHIL-DCM-0.8-5.00     SPO-CHIL   DCM      0.8-5.00                2
# SPO-SPSG-MIX-0.8-5.00     SPO-SPSG   MIX      0.8-5.00                7
# SPO-PEOD-MES-0.8-5.00     SPO-PEOD   MES      0.8-5.00                1
# SPO-SPSG-MES-0.8-5.00     SPO-SPSG   MES      0.8-5.00                7
# SPO-CHIL-MES-0.8-5.00     SPO-CHIL   MES      0.8-5.00                1
#
#                                                                   err_list  \
# SPO-all-DCM-0.8-5.00     ERR1726527, ERR1726579, ERR1726584, ERR1726609...
# SPO-all-DCM-180-2000.00  ERR1700911, ERR1726550, ERR1726552, ERR1726566...
# SPO-all-SRF-0.8-5.00     ERR1726556, ERR1726564, ERR1726567, ERR1726569...
# SPO-all-SRF-180-2000.00  ERR1726541, ERR1726543, ERR1726561, ERR1726586...
# SPO-all-SRF-20-180.00    ERR1726524, ERR1726525, ERR1726528, ERR1726544...
# ...                                                                    ...
# SPO-CHIL-DCM-0.8-5.00                                 ERR868358, ERR868505
# SPO-SPSG-MIX-0.8-5.00    ERR868359, ERR868360, ERR868371, ERR868426, ER...
# SPO-PEOD-MES-0.8-5.00                                            ERR868362
# SPO-SPSG-MES-0.8-5.00    ERR868365, ERR868379, ERR868417, ERR868443, ER...
# SPO-CHIL-MES-0.8-5.00                                            ERR868377
#
#                          total_length  total_num_contigs  largest_contig  \
# SPO-all-DCM-0.8-5.00       4407251549            2165492         1091547
# SPO-all-DCM-180-2000.00    1176646817             757959           84044
# SPO-all-SRF-0.8-5.00       9706949089            4828681         1369037
# SPO-all-SRF-180-2000.00    6202110831            3546733          547879
# SPO-all-SRF-20-180.00      6335042238            3793633          117836
# ...                               ...                ...             ...
# SPO-CHIL-DCM-0.8-5.00       415943773             196849          313467
# SPO-SPSG-MIX-0.8-5.00      1529539954             631734          830682
# SPO-PEOD-MES-0.8-5.00       257756389              97796          312655
# SPO-SPSG-MES-0.8-5.00      1432914120             656879          933592
# SPO-CHIL-MES-0.8-5.00       143809522              42893          493709
#
#                          GC_percent   N50      L50
# SPO-all-DCM-0.8-5.00          52.04  2042   526694
# SPO-all-DCM-180-2000.00       40.12  1476   260122
# SPO-all-SRF-0.8-5.00          51.59  2015  1202542
# SPO-all-SRF-180-2000.00       38.38  1681  1063188
# SPO-all-SRF-20-180.00         40.03  1619  1224089
# ...                             ...   ...      ...
# SPO-CHIL-DCM-0.8-5.00         50.82  2169    43905
# SPO-SPSG-MIX-0.8-5.00         55.04  2685   114682
# SPO-PEOD-MES-0.8-5.00         50.68  3056    13237
# SPO-SPSG-MES-0.8-5.00         53.24  2258   143325
# SPO-CHIL-MES-0.8-5.00         48.22  6543     2560
#
# [100 rows x 11 columns]

# %%
out_table.to_csv('final/TableS1_Assembly_stats.csv')

# %% [markdown]
# # Eukaryotic MAG summary table

# %%
mag_quast = pd.read_csv('mag_quast_report.txt', sep='\t', index_col=0)
mag_quast.index = mag_quast.index.str.replace('_', '-').str.replace('-bin', '_bin')

# %%
pfam = pd.read_csv('pfam-annotation.csv',index_col=0)
kegg = pd.read_csv('total_ko-annot.tab', sep=' ', index_col=0, header=None)
kegg.index = kegg.index.str.strip('.kofamscan.mapper.out')
kegg.columns = ['total_kegg']
total_proteins = pd.read_csv('total_proteins.tab', sep=' ', index_col=0)
total_proteins.index = total_proteins.index.str.strip('.faa')
unique = pd.read_csv('uniqe_pfam_kegg.csv',index_col=0)
eukcc = pd.read_csv('eukcc_completeness.csv',index_col=0)
busco = pd.read_csv('busco-update-2021-01-12.tsv',sep='\t',index_col=0)
busco_cc = pd.read_csv('EUK_BUSCO_CC.csv', index_col=0)
tax = pd.read_csv('2021-03-final-estimated_taxonomy.csv', index_col=0)
tax.columns = ['eukulele_taxonomy']
tax_split = pd.read_csv('2021-03-final-estimated_taxonomy_split.csv', index_col=0)
mmseqs_tax = pd.read_csv('../data/mmseqs-taxonomy.tsv', sep='\t', index_col=0)
mmseqs_tax['combo']=mmseqs_tax['kingdom'].str.cat(mmseqs_tax[['clade', 'phylum', 'class', 'subclass', 'order', 'family',
       'species',]].astype(str), sep=";").str.replace('.','-')
mmseqs_tax['mmseqs_taxonomy'] = 'Eukaryota;' + mmseqs_tax['combo'].astype(str)

# %%
full_stats = mag_quast.merge(total_proteins, left_index=True, right_index=True).merge(pfam, 
        left_index=True, right_index=True).merge(kegg, left_index=True, right_index=True).merge(unique,
        left_index=True, right_index=True).merge(busco_cc, 
        left_index=True, right_index=True).merge(eukcc, 
        left_index=True, right_index=True, how='outer').merge(tax, 
        left_index=True, right_index=True).merge(tax_split, left_index=True, right_index=True).merge(mmseqs_tax, left_index=True, right_index= True)
subset_for_table = full_stats[['eukulele_taxonomy','mmseqs_taxonomy','Total length','# contigs (>= 0 bp)', 
       'Total length (>= 5000 bp)', 'Total length (>= 10000 bp)',
         'Total length (>= 50000 bp)', 
        'GC (%)', 'N50', 'L50', '0', 'num_annotated', 'total_kegg', 'pfam','kegg', 'Completeness','Contamination', 'eukcc_completeness','eukcc_contamination','eukcc_lineage']]
subset_for_table.columns = ['eukulele_taxonomy','mmseqs_taxonomy','total_length', 'total_num_contigs', 'total_length_5kb',
       'total_length_10kb', 'total_length_50kb', 
       'GC_percent', 'N50', 'L50', 'num_predicted_proteins', 'num_proteins_annotated_pfam', 
        'num_proteins_annotated_kegg', 'num_unique_pfam','num_unique_kegg', 'busco_eukaryota_odb10_completeness',
        'busco_eukaryota_odb10_contamination','eukcc_completeness','eukcc_contamination','eukcc_lineage']

subset_for_table['proportion_proteins_annoated_pfam']=100*(subset_for_table.num_proteins_annotated_pfam/subset_for_table.num_predicted_proteins)
subset_for_table['proportion_proteins_annoated_kegg']=100*(subset_for_table.num_proteins_annotated_kegg/subset_for_table.num_predicted_proteins)
subset_for_table = subset_for_table[['eukulele_taxonomy','mmseqs_taxonomy','total_length', 'total_num_contigs', 'total_length_5kb',
       'total_length_10kb', 'total_length_50kb', 
       'GC_percent', 'N50', 'L50', 'num_predicted_proteins', 'num_proteins_annotated_pfam', 
                  'proportion_proteins_annoated_pfam','num_unique_pfam','num_proteins_annotated_kegg', 'proportion_proteins_annoated_kegg','num_unique_kegg', 'busco_eukaryota_odb10_completeness','busco_eukaryota_odb10_contamination',
                            'eukcc_completeness','eukcc_contamination','eukcc_lineage']]
subset_for_table['ocean_region'] = subset_for_table.index.str.split('-').str[0]
subset_for_table['depth'] = subset_for_table.index.str.split('-').str[2]
# Out:
# /vortexfs1/home/halexander/.conda/envs/general_plotting/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /vortexfs1/home/halexander/.conda/envs/general_plotting/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
neweuk_dict = pd.read_csv('../rename/renamed-eukaryotic-mags.tsv', sep='\t', index_col=0).to_dict()['new_mag_name']
EUK_MAGS_TO_DROP = list(pd.read_csv('MAGSTODROP.list', header=None)[0])
GOODMAGS = subset_for_table.index.difference(EUK_MAGS_TO_DROP)
final_table = subset_for_table.loc[GOODMAGS]
final_table.index = final_table.index.map(neweuk_dict)

# %%
sf_dict = {'1':'0.8-5', '2':'5-20', '3':'20-180', '4':'180-2000'}
final_table['size_fraction'] = final_table.index.str.split('_').str[1].str[-1]
final_table['size_fraction']=final_table.size_fraction.map(sf_dict)

# %%
for x in ['busco_eukaryota_odb10_completeness','busco_eukaryota_odb10_contamination', 'proportion_proteins_annoated_pfam','proportion_proteins_annoated_kegg',]:
    final_table[x]=final_table[x].round(2)

# %%
final_table
# Out:
#                                                  eukulele_taxonomy  \
# TOPAZ_IOD1_E001  Eukaryota;Hacrobia;Cryptophyta;Cryptophyceae;C...
# TOPAZ_IOD1_E002                            Eukaryota;-;-;-;-;-;-;-
# TOPAZ_IOD1_E003  Eukaryota;Hacrobia;Haptophyta;Prymnesiophyceae...
# TOPAZ_IOD1_E004  Eukaryota;Hacrobia;Haptophyta;Prymnesiophyceae...
# TOPAZ_IOD1_E005  Eukaryota;Archaeplastida;Chlorophyta;Mamiellop...
# ...                                                            ...
# TOPAZ_SPS2_E022  Eukaryota;Stramenopiles;Ochrophyta;Bacillariop...
# TOPAZ_SPS2_E023                      Eukaryota;Metazoa;-;-;-;-;-;-
# TOPAZ_SPS2_E024  Eukaryota;Archaeplastida;Chlorophyta;Chloropic...
# TOPAZ_SPS2_E025                      Eukaryota;Metazoa;-;-;-;-;-;-
# TOPAZ_SPS2_E026             Eukaryota;Metazoa;Arthropoda;-;-;-;-;-
#
#                                                    mmseqs_taxonomy  \
# TOPAZ_IOD1_E001  Eukaryota;-;-;-;Cryptophyceae;-;Pyrenomonadale...
# TOPAZ_IOD1_E002                        Eukaryota;-;Sar;-;-;-;-;-;-
# TOPAZ_IOD1_E003  Eukaryota;-;Prymnesiophyceae;Haptista;Haptophy...
# TOPAZ_IOD1_E004  Eukaryota;-;Prymnesiophyceae;Haptista;Haptophy...
# TOPAZ_IOD1_E005  Eukaryota;Viridiplantae;-;Chlorophyta;Mamiello...
# ...                                                            ...
# TOPAZ_SPS2_E022  Eukaryota;-;Sar;Bacillariophyta;Coscinodiscoph...
# TOPAZ_SPS2_E023  Eukaryota;Metazoa;Opisthokonta;Arthropoda;-;-;...
# TOPAZ_SPS2_E024    Eukaryota;Viridiplantae;-;Chlorophyta;-;-;-;-;-
# TOPAZ_SPS2_E025         Eukaryota;Metazoa;Opisthokonta;-;-;-;-;-;-
# TOPAZ_SPS2_E026  Eukaryota;Metazoa;Opisthokonta;Arthropoda;Inse...
#
#                  total_length  total_num_contigs  total_length_5kb  \
# TOPAZ_IOD1_E001      37074820               8377          15520088
# TOPAZ_IOD1_E002       2801896                851            188909
# TOPAZ_IOD1_E003      30740252               7112          12314358
# TOPAZ_IOD1_E004      39191221               9102          15279501
# TOPAZ_IOD1_E005      17055374               1415          15579731
# ...                       ...                ...               ...
# TOPAZ_SPS2_E022       2727571                776            468206
# TOPAZ_SPS2_E023       4663657               1284           1007863
# TOPAZ_SPS2_E024      13957152               2682           8130431
# TOPAZ_SPS2_E025       6686567               1796           1645262
# TOPAZ_SPS2_E026       5625698               1728            532642
#
#                  total_length_10kb  total_length_50kb  GC_percent    N50  \
# TOPAZ_IOD1_E001            2726308                  0       58.27   4531
# TOPAZ_IOD1_E002                  0                  0       44.45   3208
# TOPAZ_IOD1_E003            2329232                  0       62.86   4424
# TOPAZ_IOD1_E004            2168595                  0       62.08   4404
# TOPAZ_IOD1_E005           12443612            1136508       66.20  17298
# ...                            ...                ...         ...    ...
# TOPAZ_SPS2_E022             141060                  0       33.36   3336
# TOPAZ_SPS2_E023              25306                  0       35.17   3539
# TOPAZ_SPS2_E024            2420844                  0       48.06   5594
# TOPAZ_SPS2_E025              25585                  0       41.01   3612
# TOPAZ_SPS2_E026                  0                  0       35.66   3105
#
#                   L50  ...  proportion_proteins_annoated_kegg  \
# TOPAZ_IOD1_E001  2799  ...                              16.09
# TOPAZ_IOD1_E002   352  ...                              20.41
# TOPAZ_IOD1_E003  2372  ...                              13.28
# TOPAZ_IOD1_E004  3132  ...                              13.75
# TOPAZ_IOD1_E005   291  ...                              34.70
# ...               ...  ...                                ...
# TOPAZ_SPS2_E022   291  ...                               2.61
# TOPAZ_SPS2_E023   486  ...                               3.98
# TOPAZ_SPS2_E024   815  ...                              33.66
# TOPAZ_SPS2_E025   662  ...                               2.13
# TOPAZ_SPS2_E026   708  ...                              21.80
#
#                  num_unique_kegg  busco_eukaryota_odb10_completeness  \
# TOPAZ_IOD1_E001             2922                               57.25
# TOPAZ_IOD1_E002              842                               13.73
# TOPAZ_IOD1_E003             2850                               49.41
# TOPAZ_IOD1_E004             2859                               50.98
# TOPAZ_IOD1_E005             3127                               74.90
# ...                          ...                                 ...
# TOPAZ_SPS2_E022              151                                0.78
# TOPAZ_SPS2_E023              141                                0.39
# TOPAZ_SPS2_E024             2806                               66.67
# TOPAZ_SPS2_E025               76                                0.00
# TOPAZ_SPS2_E026              948                               14.51
#
#                  busco_eukaryota_odb10_contamination  eukcc_completeness  \
# TOPAZ_IOD1_E001                                 2.75               69.57
# TOPAZ_IOD1_E002                                 0.00                 NaN
# TOPAZ_IOD1_E003                                 0.39               52.08
# TOPAZ_IOD1_E004                                 0.39                 NaN
# TOPAZ_IOD1_E005                                 0.39               94.74
# ...                                              ...                 ...
# TOPAZ_SPS2_E022                                 0.00                 NaN
# TOPAZ_SPS2_E023                                 0.00                 NaN
# TOPAZ_SPS2_E024                                 0.78               65.81
# TOPAZ_SPS2_E025                                 0.00                 NaN
# TOPAZ_SPS2_E026                                 0.00               11.47
#
#                  eukcc_contamination                  eukcc_lineage  \
# TOPAZ_IOD1_E001                 8.70     Eukaryota_Fungi_Ascomycota
# TOPAZ_IOD1_E002                  NaN                            NaN
# TOPAZ_IOD1_E003                 4.17  Eukaryota_Fungi_Microsporidia
# TOPAZ_IOD1_E004                  NaN                            NaN
# TOPAZ_IOD1_E005                 0.00                      Eukaryota
# ...                              ...                            ...
# TOPAZ_SPS2_E022                  NaN                            NaN
# TOPAZ_SPS2_E023                  NaN                            NaN
# TOPAZ_SPS2_E024                 2.14                      Eukaryota
# TOPAZ_SPS2_E025                  NaN                            NaN
# TOPAZ_SPS2_E026                 0.22              Eukaryota_Metazoa
#
#                  ocean_region  depth  size_fraction
# TOPAZ_IOD1_E001            IO    DCM          0.8-5
# TOPAZ_IOD1_E002            IO    DCM          0.8-5
# TOPAZ_IOD1_E003            IO    DCM          0.8-5
# TOPAZ_IOD1_E004            IO    DCM          0.8-5
# TOPAZ_IOD1_E005            IO    DCM          0.8-5
# ...                       ...    ...            ...
# TOPAZ_SPS2_E022           SPO    SRF           5-20
# TOPAZ_SPS2_E023           SPO    SRF           5-20
# TOPAZ_SPS2_E024           SPO    SRF           5-20
# TOPAZ_SPS2_E025           SPO    SRF           5-20
# TOPAZ_SPS2_E026           SPO    SRF           5-20
#
# [988 rows x 25 columns]

# %%
final_table.to_csv('final/TableS2_EukaryoticMAG.csv')
